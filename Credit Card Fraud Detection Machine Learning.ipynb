# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\archive (2)\creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#To check every column
pd.options.display.max_columns=None

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
#Shape of Dataset; Number of rows or columns
data.shape
# Out:
# (284807, 31)

# %%
print("Number of rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of rows 284807
# Number of columns 31

# %%
#Get infomation about Dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Check for null values
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
#All data are in the same range except for amount. so we use standard scaler for just the amount column
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
#time column could be an external deciding factor and so should be dropped
data=data.drop(['Time'],axis=1)

# %%
data.shape
# Out:
# (284807, 30)

# %%
#Check for duplicates
data.duplicated().any()
# Out:
# True

# %%
#Drop Duplicated values
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
284807-275663
# Out:
# 9144

# %%
#Handling INBALANCED DATASET;Has to be in the same range
data['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data['Class'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
#From the map, the dataset is inbalanced. inbalanced dataset is when the target class has UNEVEN distribution of observations
#Handling Inbalanced Dataset UNDERSAMPLING
#UNDERSAMPLING IS merging rows in the majority class with the minority class

# %%
normal=data[data['Class']==0]
fraud=data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 0   -2.746450 -0.267234  1.049561  1.509522  1.038407 -0.635296  0.402362
# 1   -0.589127  0.675766  0.600070 -0.168005  0.694364 -0.462049  0.555768
# 2   -0.669468  1.252753  2.076264  1.138452  0.948353  0.030055  1.141969
# 3    1.033692 -0.405279  0.121319  0.302954 -0.899241 -1.443242  0.291668
# 4   -0.737070  0.898340  2.570059  0.671457  0.045484 -0.188134  0.882024
# ..        ...       ...       ...       ...       ...       ...       ...
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
#Perform train test split
X=new_data.drop('Class',axis=1)
y=new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
#Machine learning Alogorithm LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9421052631578948

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_pred)
# Out:
# 0.9117647058823529

# %% [raw]
# f1_score(y_test,y_pred)

# %%
#Decision tree Classifier
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9052631578947369

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.92

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9108910891089109

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9680851063829787

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.8921568627450981

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9285714285714286

# %%
#VISUALIZE THE RESULTS
final_data=pd.DataFrame({'Models':['LR','DT','RF'],
             "ACC":[accuracy_score(y_test,y_pred)*100,
                   accuracy_score(y_test,y_pred2)*100,
                   accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.210526
# 1     DT  90.526316
# 2     RF  92.631579

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %%
#DISADVANTAGE OF UNDERSAMPLING:LOSS OF PLENTY VALUABLE DATA

# %%
#OVERSAMPLING USING SMOT
#NOT GENERATING DUPLICATES RATHEER CREATING SYNTHETIC DATA POINTS THAT ARE SLIGHTLY DIFFERENT FROM ORIGINAL DATA

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\archive (2)\creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data=data.drop(['Time'],axis=1)

# %%
data=data.drop_duplicates()

# %%
data['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
X=data.drop('Class',axis=1)
y=data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
# !pip install imbalanced-learn
# Out:
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# ...

# %%
#USING SMOT OVERSAMPLING
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res=SMOTE().fit_resample(X,y)

# %%
y_res.shape
# Out:
# (550380,)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %%
#LOGISTIC REGRESSION
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9446745884661507

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.972854353164092

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9148046470192535

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9429369214047448

# %%
#DECISION TREE
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9985192049129692

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9978936664729808

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9991455011544825

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9985191914603679

# %%
#RANDOM FOREST
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9999091536756423

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.999818224783233

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999091041303083

# %%
#VISUALIZE RESULT
final_data=pd.DataFrame({'Models':['LR','DT','RF'],
             "ACC":[accuracy_score(y_test,y_pred1)*100,
                   accuracy_score(y_test,y_pred2)*100,
                   accuracy_score(y_test,y_pred3)*100]})

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %%
#SAVE THE BEST MODEL
#TRAIN THE BEST MODEL ON ENTIRE DATASET AFTER OVERSAMPLING
rf1=RandomForestClassifier()
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"Credit_Card_model")
# Out:
# ['Credit_Card_model']

# %%
model=joblib.load("Credit_Card_model")
